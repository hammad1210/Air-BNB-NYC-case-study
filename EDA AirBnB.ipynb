# %%
import pandas as pd 
import numpy as np

# %%
#visualization libraries
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# # Data sourcing.
#
# ## Reading files.

# %%
airbnb=pd.read_csv("AB_NYC_2019.csv")
airbnb.head()
# Out:
#      id                                              name  host_id  \
# 0  2539                Clean & quiet apt home by the park     2787
# 1  2595                             Skylit Midtown Castle     2845
# 2  3647               THE VILLAGE OF HARLEM....NEW YORK !     4632
# 3  3831                   Cozy Entire Floor of Brownstone     4869
# 4  5022  Entire Apt: Spacious Studio/Loft by central park     7192
#
#      host_name neighbourhood_group neighbourhood  latitude  longitude  \
# 0         John            Brooklyn    Kensington  40.64749  -73.97237
# 1     Jennifer           Manhattan       Midtown  40.75362  -73.98377
# 2    Elisabeth           Manhattan        Harlem  40.80902  -73.94190
# 3  LisaRoxanne            Brooklyn  Clinton Hill  40.68514  -73.95976
# 4        Laura           Manhattan   East Harlem  40.79851  -73.94399
#
#          room_type  price  minimum_nights  number_of_reviews last_review  \
# ...

# %% [markdown]
# ## Checking the rows and columns in the form of shape.

# %%
airbnb.shape
# Out:
# (48895, 16)

# %% [markdown]
# ## Checking the variable types as in info. if it requires any conversion

# %%
airbnb.info(verbose= True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48895 entries, 0 to 48894
# Data columns (total 16 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              48895 non-null  int64
#  1   name                            48879 non-null  object
#  2   host_id                         48895 non-null  int64
#  3   host_name                       48874 non-null  object
#  4   neighbourhood_group             48895 non-null  object
#  5   neighbourhood                   48895 non-null  object
#  6   latitude                        48895 non-null  float64
#  7   longitude                       48895 non-null  float64
#  8   room_type                       48895 non-null  object
#  9   price                           48895 non-null  int64
#  10  minimum_nights                  48895 non-null  int64
#  11  number_of_reviews               48895 non-null  int64
# ...

# %%
airbnb['last_review']=pd.to_datetime(airbnb['last_review'])

# %%
pd.options.display.max_rows = 500

# %%
airbnb.head(20)
# Out:
#       id                                              name  host_id  \
# 0   2539                Clean & quiet apt home by the park     2787
# 1   2595                             Skylit Midtown Castle     2845
# 2   3647               THE VILLAGE OF HARLEM....NEW YORK !     4632
# 3   3831                   Cozy Entire Floor of Brownstone     4869
# 4   5022  Entire Apt: Spacious Studio/Loft by central park     7192
# 5   5099         Large Cozy 1 BR Apartment In Midtown East     7322
# 6   5121                                   BlissArtsSpace!     7356
# 7   5178                  Large Furnished Room Near B'way      8967
# 8   5203                Cozy Clean Guest Room - Family Apt     7490
# 9   5238                Cute & Cozy Lower East Side 1 bdrm     7549
# 10  5295                  Beautiful 1br on Upper West Side     7702
# 11  5441                   Central Manhattan/near Broadway     7989
# 12  5803    Lovely Room 1, Garden, Best Area, Legal rental     9744
# ...

# %%
airbnb.info(verbose= True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48895 entries, 0 to 48894
# Data columns (total 16 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              48895 non-null  int64
#  1   name                            48879 non-null  object
#  2   host_id                         48895 non-null  int64
#  3   host_name                       48874 non-null  object
#  4   neighbourhood_group             48895 non-null  object
#  5   neighbourhood                   48895 non-null  object
#  6   latitude                        48895 non-null  float64
#  7   longitude                       48895 non-null  float64
#  8   room_type                       48895 non-null  object
#  9   price                           48895 non-null  int64
#  10  minimum_nights                  48895 non-null  int64
#  11  number_of_reviews               48895 non-null  int64
# ...

# %% [markdown]
# ## Total count of NA values

# %%
airbnb.isna().sum().sum()
# Out:
# 20141

# %% [markdown]
# ## Check missing values in percentage.

# %%
((airbnb.isnull().sum()/len(airbnb))*100).sort_values(ascending=False)
# Out:
# reviews_per_month                 20.558339
# last_review                       20.558339
# host_name                          0.042949
# name                               0.032723
# availability_365                   0.000000
# calculated_host_listings_count     0.000000
# number_of_reviews                  0.000000
# minimum_nights                     0.000000
# price                              0.000000
# room_type                          0.000000
# longitude                          0.000000
# latitude                           0.000000
# neighbourhood                      0.000000
# neighbourhood_group                0.000000
# host_id                            0.000000
# id                                 0.000000
# dtype: float64

# %% [markdown]
# ## Checking the nature of columns if it requires conversion

# %%
airbnb[['reviews_per_month','last_review','host_name','name']]
# Out:
#        reviews_per_month last_review      host_name  \
# 0                   0.21  2018-10-19           John
# 1                   0.38  2019-05-21       Jennifer
# 2                    NaN         NaT      Elisabeth
# 3                   4.64  2019-05-07    LisaRoxanne
# 4                   0.10  2018-11-19          Laura
# ...                  ...         ...            ...
# 48890                NaN         NaT        Sabrina
# 48891                NaN         NaT        Marisol
# 48892                NaN         NaT  Ilgar & Aysel
# 48893                NaN         NaT            Taz
# 48894                NaN         NaT     Christophe
#
#                                                     name
# 0                     Clean & quiet apt home by the park
# 1                                  Skylit Midtown Castle
# 2                    THE VILLAGE OF HARLEM....NEW YORK !
# 3                        Cozy Entire Floor of Brownstone
# ...

# %%
airbnb[['reviews_per_month','last_review','host_name','name']].describe()
# Out:
#        reviews_per_month
# count       38843.000000
# mean            1.373221
# std             1.680442
# min             0.010000
# 25%             0.190000
# 50%             0.720000
# 75%             2.020000
# max            58.500000

# %% [markdown]
# ## Imputing values.

# %%
#Replacing the missing values by their respectve mode values

airbnb['reviews_per_month'].fillna(0.72, inplace = True)

# %%
((airbnb.isnull().sum()/len(airbnb))*100).sort_values(ascending=False)
# Out:
# last_review                       20.558339
# host_name                          0.042949
# name                               0.032723
# availability_365                   0.000000
# calculated_host_listings_count     0.000000
# reviews_per_month                  0.000000
# number_of_reviews                  0.000000
# minimum_nights                     0.000000
# price                              0.000000
# room_type                          0.000000
# longitude                          0.000000
# latitude                           0.000000
# neighbourhood                      0.000000
# neighbourhood_group                0.000000
# host_id                            0.000000
# id                                 0.000000
# dtype: float64

# %%
airbnb[['price']].describe()
# Out:
#               price
# count  48895.000000
# mean     152.720687
# std      240.154170
# min        0.000000
# 25%       69.000000
# 50%      106.000000
# 75%      175.000000
# max    10000.000000

# %%
plt.boxplot(airbnb['price'])
plt.show()

# %%
sns.set_theme(style="whitegrid")

ax = sns.boxplot(x=airbnb["price"])

# %%
import plotly.express as px

# %%
fig_box = px.box(airbnb["price"], x='price', orientation='h',
                 width=800, height=500)
fig_box.show()
# Out:
# <div>
#
#
#             <div id="57148382-7718-4e5e-a145-5d5aaf8c8dc7" class="plotly-graph-div" style="height:500px; width:800px;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("57148382-7718-4e5e-a145-5d5aaf8c8dc7")) {
#                     Plotly.newPlot(
#                         '57148382-7718-4e5e-a145-5d5aaf8c8dc7',
# ...

# %%
airbnb[['minimum_nights']].describe()
# Out:
#        minimum_nights
# count    48895.000000
# mean         7.029962
# std         20.510550
# min          1.000000
# 25%          1.000000
# 50%          3.000000
# 75%          5.000000
# max       1250.000000

# %%
airbnb[['reviews_per_month']].describe()
# Out:
#        reviews_per_month
# count       48895.000000
# mean            1.238930
# std             1.520861
# min             0.010000
# 25%             0.280000
# 50%             0.720000
# 75%             1.580000
# max            58.500000

# %%
AirBnB = airbnb.loc[~(airbnb['price'] == 0)]

# %%
AirBnB
# Out:
#              id                                               name   host_id  \
# 0          2539                 Clean & quiet apt home by the park      2787
# 1          2595                              Skylit Midtown Castle      2845
# 2          3647                THE VILLAGE OF HARLEM....NEW YORK !      4632
# 3          3831                    Cozy Entire Floor of Brownstone      4869
# 4          5022   Entire Apt: Spacious Studio/Loft by central park      7192
# ...         ...                                                ...       ...
# 48890  36484665    Charming one bedroom - newly renovated rowhouse   8232441
# 48891  36485057      Affordable room in Bushwick/East Williamsburg   6570630
# 48892  36485431            Sunny Studio at Historical Neighborhood  23492952
# 48893  36485609               43rd St. Time Square-cozy single bed  30985759
# 48894  36487245  Trendy duplex in the very heart of Hell's Kitchen  68119814
#
# ...

# %%
sns.pairplot(airbnb[['id','name','host_id','host_name',
                         'neighbourhood_group','neighbourhood','room_type',
                         'price','minimum_nights','number_of_reviews','last_review',
                         'reviews_per_month','calculated_host_listings_count','availability_365']])
plt.show()

# %%
sns.pairplot(airbnb[['id','number_of_reviews']])
plt.show()

# %%
airbnb.to_csv('AB_NYC_2019_new.csv')
